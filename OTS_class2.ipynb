# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumar089/Class-notes/blob/main/OTS_class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tuples

# %%
my_phone_tup = ("iphone 5",25,True)

# %%
my_phone_tup
# Out:
# ('iphone 5', 25, True)

# %%
type(my_phone_tup)
# Out:
# tuple

# %%
print(my_phone_tup)
# Out:
# ('iphone 5', 25, True)

# %%
my_phone_tup[0]
# Out:
# 'iphone 5'

# %%
for i in my_phone_tup:
    print(i*2)
# Out:
# iphone 5iphone 5
# 50
# 2

# %%
my_phone_tup.append('redmi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3691309140.py in <cell line: 0>()
# ----> 1 my_phone_tup.append('redmi')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
my_phone_tup[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3681099954.py in <cell line: 0>()
# ----> 1 my_phone_tup[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list = [1,5,4,10,'Hi']

# %%
my_tuple = (4,5,3,'Hello tup')

# %%
my_list.append('Hello world')

# %%
my_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-376848641.py in <cell line: 0>()
# ----> 1 my_list
#
# NameError: name 'my_list' is not defined

# %%
my_list.pop()

# %%
my_list

# %%
my_tuple.append('Hello all')

# %%
import time

# %%
for i in list(range(50)):
    print(i,i%2,i%2==0)

# %%
start = time.time()
for i in list(range(50)):
    print(i%2==0)

end_time = time.time()

elapsed_time = end_time - start
print(f'Total elapsed time is {elapsed_time}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1779198257.py in <cell line: 0>()
# ----> 1 start = time.time()
#       2 for i in list(range(50)):
#       3     print(i%2==0)
#       4
#       5 end_time = time.time()
#
# NameError: name 'time' is not defined

# %%
start = time.time()
for i in tuple(range(50)):
    print(i%2==0)

end_time = time.time()

elapsed_time = end_time - start
print(f'Total elapsed time is {elapsed_time}')

# %%
list(range(5))

# %%
tuple(range(10))

# %%
my_phone_tup
# Out:
# ('iphone 5', 25, True)

# %% [markdown]
# # Set

# %%
my_set = {1,2,3,4}

# %%
type(my_set)
# Out:
# set

# %%
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set.add(5)

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
A = {1,2,3,4,5}

# %%
B = {3,4,5,6}

# %%
print(A)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(B)
# Out:
# {3, 4, 5, 6}

# %% [markdown]
# # We will perform 4 Operations in the set

# %%
print(A|B) # Union Operation
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(B|A)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(A & B) # INtersection Operation
# Out:
# {3, 4, 5}

# %%
# Difference Operation

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
B
# Out:
# {3, 4, 5, 6}

# %%
print(A - B)
# Out:
# {1, 2}

# %%
print(B - A)
# Out:
# {6}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
my_list = list(my_set)

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 4]

# %%
A
# Out:
# {1, 2, 3, 4, 5}

# %%
B
# Out:
# {3, 4, 5, 6}

# %%
my_set
# Out:
# {1, 2, 3, 4, 5}

# %%
for i in my_set:
    print(i*2)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
from typing import Sequence
my_new_set = set(['iphone 5', 100, 5.2, True])

# %%
my_new_set
# Out:
# {100, 5.2, True, 'iphone 5'}

# %%
my_new_set.add()

# %%
my_new_set
# Out:
# {10, 100, 10000, 15, 5.2, True, 'iphone 5'}

# %%
my_new_set.pop()
# Out:
# True

# %%
my_new_set.discard(10000)

# %%
my_new_set
# Out:
# {10, 100, 15, 5.2, 'iphone 5'}

# %%
word = input('Enter the value ')
letter = set(word)
print(letter)
# Out:
# Enter the value letter
# {'l', 't', 'r', 'e'}

# %% [markdown]
# # Dictionary

# %%
student = {"name":"Akash","age":21, "isTeacher":True}

# %%
print(student)
# Out:
# {'name': 'Akash', 'age': 21, 'isTeacher': True}

# %%
type(student)
# Out:
# dict

# %%
print(student["name"])
# Out:
# Akash

# %%
print(student['isTeacher'])
# Out:
# True

# %%
student["age"] = 30

# %%
print(student)
# Out:
# {'name': 'Akash', 'age': 30, 'isTeacher': True}

# %%
student.pop("age")
# Out:
# 30

# %%
student
# Out:
# {'name': 'Akash', 'isTeacher': True}

# %%
student.update({"age":35})

# %%
student
# Out:
# {'name': 'Akash', 'isTeacher': True, 'age': 35}

# %%
for key in  student:
    print(key,":",student[key])
# Out:
# name : Akash
# isTeacher : True
# age : 35

# %%
student.values()
# Out:
# dict_values(['Akash', True, 35])

# %%
student.keys()
# Out:
# dict_keys(['name', 'isTeacher', 'age'])

# %%
student.items()
# Out:
# dict_items([('name', 'Akash'), ('isTeacher', True), ('age', 35)])
