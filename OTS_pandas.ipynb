# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumar089/Class-notes/blob/main/OTS_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Series :- Series is a 1D data
#
# # DataFrame : This is a 2D data (row , col)

# %%
ages = [10,20,14,15]

# %%
ages = pd.Series([40,50,30,10])

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages
# Out:
# 0    40
# 1    50
# 2    30
# 3    10
# dtype: int64

# %%
ages = pd.Series([10,20,30,40],index=["Raj","Ravi","Ankit","Aman"])

# %%
print(ages)
# Out:
# Raj      10
# Ravi     20
# Ankit    30
# Aman     40
# dtype: int64

# %%
ages = pd.Series(data=ages,index=["Raj","Ravi","Ankit","Aman"])

# %%
print(ages)
# Out:
# Raj      10
# Ravi     20
# Ankit    30
# Aman     40
# dtype: int64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.shape
# Out:
# (4,)

# %%
data = {
    "maths":20,
    "Science":30,
    "Sst":50
}

# %%
new_series  = pd.Series(data=data)

print(new_series)
# Out:
# maths      20
# Science    30
# Sst        50
# dtype: int64

# %%
marks = pd.Series([40,60,50])

# %%
result  = marks>40

print(result)
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
marks
# Out:
# 0    40
# 1    60
# 2    50
# dtype: int64

# %%
print(marks.mean())
# Out:
# 50.0

# %%
print(marks.std())
# Out:
# 10.0

# %%
print(marks.min())
# Out:
# 40

# %%
print(marks.max())
# Out:
# 60

# %%
marks
# Out:
# 0    40
# 1    60
# 2    50
# dtype: int64

# %%
new_series
# Out:
# maths      20
# Science    30
# Sst        50
# dtype: int64

# %%
grades = new_series.apply(lambda x:"Pass" if x >=30 else "Fail")

# %%
print(grades)
# Out:
# maths      Fail
# Science    Pass
# Sst        Pass
# dtype: object

# %% [markdown]
# ## DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
pd.DataFrame?

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
my_list = ['I','am','building','a','Machine','Learning','Model']

# %%
type(my_list)
# Out:
# list

# %%
df = pd.DataFrame(my_list)
print(df)
type(df)
# Out:
#           0
# 0         I
# 1        am
# 2  building
# 3         a
# 4   Machine
# 5  Learning
# 6     Model
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (7, 1)

# %%
import numpy as np
import pandas as pd

# %%
data = np.array([[5,7,8],[3,4,5],[2,5,8]])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (3, 3)

# %%
df = pd.DataFrame(data,columns=['Marks A','Marks B','Marks C'])

# %%
df
# Out:
#    Marks A  Marks B  Marks C
# 0        5        7        8
# 1        3        4        5
# 2        2        5        8

# %%
my_dictionary  = {
    'studentName':['Arvind','Kushal','Sam','Sundar'],
    'Subject':['Maths','Physics','CS','Chemistry'],
    'Marks':[40,50,60,70]
}

# %%
df = pd.DataFrame(my_dictionary)

# %%
print(df)
# Out:
#   studentName    Subject  Marks
# 0      Arvind      Maths     40
# 1      Kushal    Physics     50
# 2         Sam         CS     60
# 3      Sundar  Chemistry     70
