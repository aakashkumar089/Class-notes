# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumar089/Class-notes/blob/main/OTS_File_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("poem.txt",mode="r")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='poem.txt' mode='r' encoding='utf-8'>

# %%
output = f.read()

# %%
print(output)
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
#
# ---
#
# ### **Invictus**
#
# *By William Ernest Henley (1849–1903)*
#
# > Out of the night that covers me,
# > Black as the pit from pole to pole,
# > I thank whatever gods may be
# > For my unconquerable soul.
# >
# > In the fell clutch of circumstance
# > I have not winced nor cried aloud.
# > Under the bludgeonings of chance
# > My head is bloody, but unbowed.
# >
# > Beyond this place of wrath and tears
# > Looms but the Horror of the shade,
# > And yet the menace of the years
# > Finds, and shall find, me unafraid.
# >
# > It matters not how strait the gate,
# > How charged with punishments the scroll,
# > **I am the master of my fate,
# > I am the captain of my soul.**

# %% [markdown]
# # Solution 1

# %%
f.seek(0)
print(f.read())
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
#
# ---
#
# ### **Invictus**
#
# *By William Ernest Henley (1849–1903)*
#
# > Out of the night that covers me,
# > Black as the pit from pole to pole,
# > I thank whatever gods may be
# > For my unconquerable soul.
# >
# > In the fell clutch of circumstance
# > I have not winced nor cried aloud.
# > Under the bludgeonings of chance
# > My head is bloody, but unbowed.
# >
# > Beyond this place of wrath and tears
# > Looms but the Horror of the shade,
# > And yet the menace of the years
# > Finds, and shall find, me unafraid.
# >
# > It matters not how strait the gate,
# > How charged with punishments the scroll,
# > **I am the master of my fate,
# > I am the captain of my soul.**

# %%
# Solution 2
f.close()
f = open("poem.txt",'r')
output = f.read()

# %%
print(output)
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
#
# ---
#
# ### **Invictus**
#
# *By William Ernest Henley (1849–1903)*
#
# > Out of the night that covers me,
# > Black as the pit from pole to pole,
# > I thank whatever gods may be
# > For my unconquerable soul.
# >
# > In the fell clutch of circumstance
# > I have not winced nor cried aloud.
# > Under the bludgeonings of chance
# > My head is bloody, but unbowed.
# >
# > Beyond this place of wrath and tears
# > Looms but the Horror of the shade,
# > And yet the menace of the years
# > Finds, and shall find, me unafraid.
# >
# > It matters not how strait the gate,
# > How charged with punishments the scroll,
# > **I am the master of my fate,
# > I am the captain of my soul.**

# %%
with open("poem.txt",'r') as f:
    data = f.read()

# %%
print(data)
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
#
# ---
#
# ### **Invictus**
#
# *By William Ernest Henley (1849–1903)*
#
# > Out of the night that covers me,
# > Black as the pit from pole to pole,
# > I thank whatever gods may be
# > For my unconquerable soul.
# >
# > In the fell clutch of circumstance
# > I have not winced nor cried aloud.
# > Under the bludgeonings of chance
# > My head is bloody, but unbowed.
# >
# > Beyond this place of wrath and tears
# > Looms but the Horror of the shade,
# > And yet the menace of the years
# > Finds, and shall find, me unafraid.
# >
# > It matters not how strait the gate,
# > How charged with punishments the scroll,
# > **I am the master of my fate,
# > I am the captain of my soul.**

# %% [markdown]
# ## Read the file line by line

# %%
with open("poem.txt","r") as f:
    lines = f.readlines()

# %%
for kkk in lines:
    print(kkk.strip())
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
#
# ---
#
# ### **Invictus**
#
# *By William Ernest Henley (1849–1903)*
#
# > Out of the night that covers me,
# > Black as the pit from pole to pole,
# > I thank whatever gods may be
# > For my unconquerable soul.
# >
# > In the fell clutch of circumstance
# > I have not winced nor cried aloud.
# > Under the bludgeonings of chance
# > My head is bloody, but unbowed.
# >
# > Beyond this place of wrath and tears
# > Looms but the Horror of the shade,
# > And yet the menace of the years
# > Finds, and shall find, me unafraid.
# >
# > It matters not how strait the gate,
# > How charged with punishments the scroll,
# > **I am the master of my fate,
# > I am the captain of my soul.**

# %%
with open("poem.txt","r") as f:
    line = f.readline()

# %%
print(line)
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**

# %%
f = open("poem.txt","r")

output = f.readline()
print(output)
# Out:
# Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**

# %%
output = f.readline()
print(output)
# Out:
# It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.

# %%
output = f.readline()
print(output)

# %%
with open("poem.txt","r") as f:
    lines = f.readlines()

i = 0
for line in lines:
    print(i,line.strip())
    i = i+1
# Out:
# 0 Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**
# 1 It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.
# 2
# 3 ---
# 4
# 5 ### **Invictus**
# 6
# 7 *By William Ernest Henley (1849–1903)*
# 8
# 9 > Out of the night that covers me,
# 10 > Black as the pit from pole to pole,
# 11 > I thank whatever gods may be
# 12 > For my unconquerable soul.
# 13 >
# 14 > In the fell clutch of circumstance
# 15 > I have not winced nor cried aloud.
# 16 > Under the bludgeonings of chance
# 17 > My head is bloody, but unbowed.
# 18 >
# 19 > Beyond this place of wrath and tears
# 20 > Looms but the Horror of the shade,
# 21 > And yet the menace of the years
# 22 > Finds, and shall find, me unafraid.
# 23 >
# 24 > It matters not how strait the gate,
# 25 > How charged with punishments the scroll,
# 26 > **I am the master of my fate,
# ...

# %%
print(lines)
# Out:
# ['Sure — here’s a **motivational poem** by the famous poet **William Ernest Henley**, titled **“Invictus.”**\n', 'It’s one of the most powerful and inspiring poems ever written — about courage, self-mastery, and resilience in the face of hardship.\n', '\n', '---\n', '\n', '### **Invictus**\n', '\n', '*By William Ernest Henley (1849–1903)*\n', '\n', '> Out of the night that covers me,\n', '> Black as the pit from pole to pole,\n', '> I thank whatever gods may be\n', '> For my unconquerable soul.\n', '>\n', '> In the fell clutch of circumstance\n', '> I have not winced nor cried aloud.\n', '> Under the bludgeonings of chance\n', '> My head is bloody, but unbowed.\n', '>\n', '> Beyond this place of wrath and tears\n', '> Looms but the Horror of the shade,\n', '> And yet the menace of the years\n', '> Finds, and shall find, me unafraid.\n', '>\n', '> It matters not how strait the gate,\n', '> How charged with punishments the scroll,\n', '> **I am the master of my fate,\n', '> I am the ca
# ...

# %%
#Create a file

file = open("demo.txt",mode="w")
file.write("Write me a poem for my school\n")
file.write("Because i have to perform in childrens day")


file.close()

# %%
# method 2
with open("my_notes.txt","w") as f:
    f.write("My physics notes is with you\n")
    f.write("My chem notes is with me\n")

# %%
my_collegues = ["Rohan","Lakshmi","Ravi"]

with open("my_friends.txt","w") as f:
    for names in my_collegues:
        f.write(names +'\n')

# %%
with open("my_friends.txt","a") as f:
    f.write("\n     Shoeb")
