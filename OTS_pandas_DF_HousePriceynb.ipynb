# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumar089/Class-notes/blob/main/OTS_pandas_DF_HousePriceynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/House Price Prediction Dataset.csv')

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.tail()
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# 1995     No  295620
# 1996    Yes  580929
# 1997     No  476925
# 1998    Yes  161119
# 1999     No  482525

# %%
df.shape
# Out:
# (2000, 10)

# %%
df.dtypes
# Out:
# Id            int64
# Area          int64
# Bedrooms      int64
# Bathrooms     int64
# Floors        int64
# YearBuilt     int64
# Location     object
# Condition    object
# Garage       object
# Price         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   object
#  7   Condition  2000 non-null   object
#  8   Garage     2000 non-null   object
#  9   Price      2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
new_cols = df[['Area','Bedrooms']]

# %%
df['new_cols']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_cols'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1764990464.py in <cell line: 0>()
# ----> 1 df['new_cols']
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='object')

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
type(my_col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2900485492.py in <cell line: 0>()
# ----> 1 type(my_col)
#
# NameError: name 'my_col' is not defined

# %%
df['my_new_space']=df['Bathrooms'] + df['Bedrooms']

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df['new_Bedroom_area'] = df['Bedrooms'] * 100

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  my_new_space  new_Bedroom_area
# 0     No  149919             9               500
# 1     No  424998             9               500
# 2     No  266746             4               200
# 3    Yes  244020             6               400
# 4    Yes  636056             5               100

# %%
df['percentage_area'] = (df['new_Bedroom_area']/df['Area']) * 100

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  my_new_space  new_Bedroom_area  percentage_area
# 0     No  149919             9               500        36.764706
# 1     No  424998             9               500        11.704120
# 2     No  266746             4               200         5.567929
# 3    Yes  244020             6               400        41.407867
# 4    Yes  636056             5               100         2.030045

# %%
df.drop('my_new_space',axis=1)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df = df.drop('my_new_space',axis=1)

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  new_Bedroom_area  percentage_area
# 0     No  149919               500        36.764706
# 1     No  424998               500        11.704120
# 2     No  266746               200         5.567929
# 3    Yes  244020               400        41.407867
# 4    Yes  636056               100         2.030045

# %%
df.drop('new_Bedroom_area',axis=1)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  new_Bedroom_area  percentage_area
# 0     No  149919               500        36.764706
# 1     No  424998               500        11.704120
# 2     No  266746               200         5.567929
# 3    Yes  244020               400        41.407867
# 4    Yes  636056               100         2.030045

# %%
df = df.drop('new_Bedroom_area',axis=1)

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  percentage_area
# 0     No  149919        36.764706
# 1     No  424998        11.704120
# 2     No  266746         5.567929
# 3    Yes  244020        41.407867
# 4    Yes  636056         2.030045

# %%
df
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
df = df.set_index('Id')

# %%
df.head()
# Out:
#     Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage  \
# Id
# 1   1360         5          4       3       1970  Downtown  Excellent     No
# 2   4272         5          4       3       1958  Downtown  Excellent     No
# 3   3592         2          2       3       1938  Downtown       Good     No
# 4    966         4          2       2       1902  Suburban       Fair    Yes
# 5   4926         1          4       2       1975  Downtown       Fair    Yes
#
#      Price  percentage_area
# Id
# 1   149919        36.764706
# 2   424998        11.704120
# 3   266746         5.567929
# 4   244020        41.407867
# 5   636056         2.030045

# %%
df.set_index('Area')
# Out:
#       Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage  \
# Area
# 1360         5          4       3       1970  Downtown  Excellent     No
# 4272         5          4       3       1958  Downtown  Excellent     No
# 3592         2          2       3       1938  Downtown       Good     No
# 966          4          2       2       1902  Suburban       Fair    Yes
# 4926         1          4       2       1975  Downtown       Fair    Yes
# ...        ...        ...     ...        ...       ...        ...    ...
# 4994         5          4       3       1923  Suburban       Poor     No
# 3046         5          2       1       2019  Suburban       Poor    Yes
# 1062         5          1       2       1903     Rural       Poor     No
# 4062         3          1       2       1936     Urban  Excellent    Yes
# 2989         5          1       3       1903  Suburban       Fair     No
#
#        Price  percentage_area
# Area
# 1360  149919        36.764706
# ...

# %%
df.head()
# Out:
#     Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage  \
# Id
# 1   1360         5          4       3       1970  Downtown  Excellent     No
# 2   4272         5          4       3       1958  Downtown  Excellent     No
# 3   3592         2          2       3       1938  Downtown       Good     No
# 4    966         4          2       2       1902  Suburban       Fair    Yes
# 5   4926         1          4       2       1975  Downtown       Fair    Yes
#
#      Price  percentage_area
# Id
# 1   149919        36.764706
# 2   424998        11.704120
# 3   266746         5.567929
# 4   244020        41.407867
# 5   636056         2.030045

# %%
df.reset_index()
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
# ...

# %%
df.head()
# Out:
#     Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition Garage  \
# Id
# 1   1360         5          4       3       1970  Downtown  Excellent     No
# 2   4272         5          4       3       1958  Downtown  Excellent     No
# 3   3592         2          2       3       1938  Downtown       Good     No
# 4    966         4          2       2       1902  Suburban       Fair    Yes
# 5   4926         1          4       2       1975  Downtown       Fair    Yes
#
#      Price  percentage_area
# Id
# 1   149919        36.764706
# 2   424998        11.704120
# 3   266746         5.567929
# 4   244020        41.407867
# 5   636056         2.030045

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price  percentage_area
# 0     No  149919        36.764706
# 1     No  424998        11.704120
# 2     No  266746         5.567929
# 3    Yes  244020        41.407867
# 4    Yes  636056         2.030045

# %%
df.iloc[10:50]
# Out:
#     Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 10  11  1269         1          4       2       1947  Suburban       Poor
# 11  12  2891         4          4       3       1978     Urban  Excellent
# 12  13  2933         4          3       2       1901  Downtown       Poor
# 13  14  1684         1          1       1       2004     Rural       Good
# 14  15  3885         1          3       1       1970     Urban       Fair
# 15  16  4617         1          4       2       1931  Downtown       Poor
# 16  17  3404         2          1       1       1903     Urban       Fair
# 17  18   974         2          2       1       1919  Downtown       Poor
# 18  19  1582         2          2       2       2013  Suburban       Good
# 19  20  3058         5          2       2       2016  Downtown  Excellent
# 20  21  2547         4          4       2       1935  Suburban       Good
# 21  22  3247         4          3       1       1931  Downtown  Excellent
# ...

# %%
df.loc[0]
# Out:
# Id                         1
# Area                    1360
# Bedrooms                   5
# Bathrooms                  4
# Floors                     3
# YearBuilt               1970
# Location            Downtown
# Condition          Excellent
# Garage                    No
# Price                 149919
# percentage_area    36.764706
# Name: 0, dtype: object
