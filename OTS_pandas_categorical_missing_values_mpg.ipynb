# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashkumar089/Class-notes/blob/main/OTS_pandas_categorical_missing_values_mpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/mpg.csv")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.head(20)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['mpg'].mean()
# Out:
# np.float64(23.514572864321607)

# %%
df.groupby('model_year')[['mpg','cylinders']].mean()
# Out:
#                   mpg  cylinders
# model_year
# 70          17.689655   6.758621
# 71          21.250000   5.571429
# 72          18.714286   5.821429
# 73          17.100000   6.375000
# 74          22.703704   5.259259
# 75          20.266667   5.600000
# 76          21.573529   5.647059
# 77          23.375000   5.464286
# 78          24.061111   5.361111
# 79          25.093103   5.827586
# 80          33.696552   4.137931
# 81          30.334483   4.620690
# 82          31.709677   4.193548

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.groupby('model_year')[['mpg','horsepower','weight']].mean(numeric_only = True)
# Out:
#                   mpg       weight
# model_year
# 70          17.689655  3372.793103
# 71          21.250000  2995.428571
# 72          18.714286  3237.714286
# 73          17.100000  3419.025000
# 74          22.703704  2877.925926
# 75          20.266667  3176.800000
# 76          21.573529  3078.735294
# 77          23.375000  2997.357143
# 78          24.061111  2861.805556
# 79          25.093103  3055.344828
# 80          33.696552  2436.655172
# 81          30.334483  2522.931034
# 82          31.709677  2453.548387

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'],errors='coerce')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df.groupby('model_year')[['mpg','horsepower','weight']].mean(numeric_only = True)
# Out:
#                   mpg  horsepower       weight
# model_year
# 70          17.689655  147.827586  3372.793103
# 71          21.250000  107.037037  2995.428571
# 72          18.714286  120.178571  3237.714286
# 73          17.100000  130.475000  3419.025000
# 74          22.703704   94.230769  2877.925926
# 75          20.266667  101.066667  3176.800000
# 76          21.573529  101.117647  3078.735294
# 77          23.375000  105.071429  2997.357143
# 78          24.061111   99.694444  2861.805556
# 79          25.093103  101.206897  3055.344828
# 80          33.696552   77.481481  2436.655172
# 81          30.334483   81.035714  2522.931034
# 82          31.709677   81.466667  2453.548387

# %%
avg_year = df.groupby(['model_year','origin'])[['mpg','horsepower','weight']].mean()

# %%
avg_year.index
# Out:
# MultiIndex([(70, 1),
#             (70, 2),
#             (70, 3),
#             (71, 1),
#             (71, 2),
#             (71, 3),
#             (72, 1),
#             (72, 2),
#             (72, 3),
#             (73, 1),
#             (73, 2),
#             (73, 3),
#             (74, 1),
#             (74, 2),
#             (74, 3),
#             (75, 1),
#             (75, 2),
#             (75, 3),
#             (76, 1),
#             (76, 2),
#             (76, 3),
#             (77, 1),
#             (77, 2),
#             (77, 3),
#             (78, 1),
#             (78, 2),
#             (78, 3),
#             (79, 1),
#             (79, 2),
#             (79, 3),
#             (80, 1),
#             (80, 2),
#             (80, 3),
#             (81, 1),
#             (81, 2),
#             (81, 3),
#             (82, 1),
#             (82, 2),
#             (82, 3)],
#            names=['model_year', 'origin'])

# %%
avg_year.columns
# Out:
# Index(['mpg', 'horsepower', 'weight'], dtype='object')

# %%
avg_year['mpg']
# Out:
# model_year  origin
# 70          1         15.272727
#             2         25.200000
#             3         25.500000
# 71          1         18.100000
#             2         28.750000
#             3         29.500000
# 72          1         16.277778
#             2         22.000000
#             3         24.200000
# 73          1         15.034483
#             2         24.000000
#             3         20.000000
# 74          1         18.333333
#             2         27.000000
#             3         29.333333
# 75          1         17.550000
#             2         24.500000
#             3         27.500000
# 76          1         19.431818
#             2         24.250000
#             3         28.000000
# 77          1         20.722222
#             2         29.250000
#             3         27.416667
# 78          1         21.772727
#             2         24.950000
#             3         29.687500
# 79          1         23.478261
# ...

# %%
df.groupby('model_year').describe()
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %%
year_cylinder = df.groupby(['model_year','cylinders']).mean(numeric_only=True)

# %%
year_cylinder
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         4          27.461538    101.846154   77.583333  2056.384615
#            6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
# ...

# %%
year_cylinder.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
year_cylinder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 43 entries, (np.int64(70), np.int64(4)) to (np.int64(82), np.int64(6))
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           43 non-null     float64
#  1   displacement  43 non-null     float64
#  2   horsepower    43 non-null     float64
#  3   weight        43 non-null     float64
#  4   acceleration  43 non-null     float64
#  5   origin        43 non-null     float64
# dtypes: float64(6)
# memory usage: 2.3 KB

# %%
year_cylinder.loc[70]
# Out:
#                  mpg  displacement  horsepower       weight  acceleration  \
# cylinders
# 4          25.285714    107.000000   87.714286  2292.571429     16.000000
# 6          20.500000    199.000000   91.750000  2710.500000     15.500000
# 8          14.111111    367.555556  183.666667  3940.055556     11.194444
#
#              origin
# cylinders
# 4          2.285714
# 6          1.000000
# 8          1.000000

# %%
year_cylinder.loc[[70,72,73]]
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         4          25.285714    107.000000   87.714286  2292.571429
#            6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 72         3          19.000000     70.000000   97.000000  2330.000000
#            4          23.428571    111.535714   85.142857  2382.642857
#            8          13.615385    344.846154  159.692308  4228.384615
# 73         3          18.000000     70.000000   90.000000  2124.000000
#            4          22.727273    109.272727   82.909091  2338.090909
#            6          19.000000    212.250000  102.125000  2917.125000
#            8          13.200000    365.250000  170.000000  4279.050000
#
#                       acceleration    origin
# model_year cylinders
# 70         4             16.000000  2.285714
#            6             15.500000  1.000000
# ...

# %%
year_cylinder.loc[(70,8)]
# Out:
# mpg               14.111111
# displacement     367.555556
# horsepower       183.666667
# weight          3940.055556
# acceleration      11.194444
# origin             1.000000
# Name: (70, 8), dtype: float64

# %%
# Cross Section
year_cylinder.xs(key=70,axis=0,level='model_year')
# Out:
#                  mpg  displacement  horsepower       weight  acceleration  \
# cylinders
# 4          25.285714    107.000000   87.714286  2292.571429     16.000000
# 6          20.500000    199.000000   91.750000  2710.500000     15.500000
# 8          14.111111    367.555556  183.666667  3940.055556     11.194444
#
#              origin
# cylinders
# 4          2.285714
# 6          1.000000
# 8          1.000000

# %%
year_cylinder.xs(key=6,axis=0,level='cylinders')
# Out:
#                   mpg  displacement  horsepower       weight  acceleration  \
# model_year
# 70          20.500000    199.000000   91.750000  2710.500000     15.500000
# 71          18.000000    243.375000   98.875000  3171.875000     14.750000
# 73          19.000000    212.250000  102.125000  2917.125000     15.687500
# 74          17.857143    230.428571  101.666667  3320.000000     16.857143
# 75          17.583333    233.750000   96.750000  3398.333333     17.708333
# 76          20.000000    221.400000   98.700000  3349.600000     17.000000
# 77          19.500000    220.400000  102.000000  3383.000000     16.900000
# 78          19.066667    213.250000  109.833333  3314.166667     16.391667
# 79          22.950000    205.666667  105.000000  3025.833333     15.433333
# 80          25.900000    196.500000  111.000000  3145.500000     15.050000
# 81          23.428571    184.000000  100.714286  3093.571429     15.442857
# ...

# %%
[df[df['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean(numeric_only=True)
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         8          13.615385    344.846154  159.692308  4228.384615
# 73         6          19.000000    212.250000  102.125000  2917.125000
#            8          13.200000    365.250000  170.000000  4279.050000
# 74         6          17.857143    230.428571  101.666667  3320.000000
#            8          14.200000    315.200000  146.000000  4438.400000
# 75         6          17.583333    233.750000   96.750000  3398.333333
#            8          15.666667    330.500000  142.000000  4108.833333
# 76         6          20.000000    221.400000   98.700000  3349.600000
# ...

# %%
df[df['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean(numeric_only=True)
# Out:
#                             mpg  displacement  horsepower       weight  \
# model_year cylinders
# 70         6          20.500000    199.000000   91.750000  2710.500000
#            8          14.111111    367.555556  183.666667  3940.055556
# 71         6          18.000000    243.375000   98.875000  3171.875000
#            8          13.428571    371.714286  166.857143  4537.714286
# 72         8          13.615385    344.846154  159.692308  4228.384615
# 73         6          19.000000    212.250000  102.125000  2917.125000
#            8          13.200000    365.250000  170.000000  4279.050000
# 74         6          17.857143    230.428571  101.666667  3320.000000
#            8          14.200000    315.200000  146.000000  4438.400000
# 75         6          17.583333    233.750000   96.750000  3398.333333
#            8          15.666667    330.500000  142.000000  4108.833333
# 76         6          20.000000    221.400000   98.700000  3349.600000
# ...

# %%
df.select_dtypes(include='number').agg(['median','mean','std'])
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# median  23.000000   4.000000    148.500000   93.500000  2803.500000
# mean    23.514573   5.454774    193.425879  104.469388  2970.424623
# std      7.815984   1.701004    104.269838   38.491160   846.841774
#
#         acceleration  model_year    origin
# median     15.500000   76.000000  1.000000
# mean       15.568090   76.010050  1.572864
# std         2.757689    3.697627  0.802055

# %%
df.agg({
    'mpg':['median','mean'],
    'weight':['mean','std']
})
# Out:
#               mpg       weight
# median  23.000000          NaN
# mean    23.514573  2970.424623
# std           NaN   846.841774
